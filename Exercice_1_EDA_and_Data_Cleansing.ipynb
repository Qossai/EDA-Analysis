# %% [markdown]
# <a href="https://colab.research.google.com/github/Qossai/EDA-Analysis/blob/main/Exercice_1_EDA_and_Data_Cleansing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sweetviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 20.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Import the required libraries

# %%
import pandas as pd
import sweetviz as sv
from google.colab import files

# %% [markdown]
# ## Load the dataset

# %%
uploaded = files.upload()
df = pd.read_csv('hrm-employee-attrition_unclean.csv')
# Out:
#      <input type="file" id="files-d1389ade-d28e-48a2-8863-f7e7701e1d0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1389ade-d28e-48a2-8863-f7e7701e1d0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Quick look at the dataset structure

# %%
df.head()
# Out:
#    Unnamed: 0 Attrition   Age     BusinessTravel  DailyRate  \
# 0           0       Yes  41.0      Travel_Rarely     1102.0
# 1           1        No  49.0  Travel_Frequently      279.0
# 2           2       Yes  37.0      Travel_Rarely     1373.0
# 3           3        No  33.0  Travel_Frequently     1392.0
# 4           4        No  27.0      Travel_Rarely      591.0
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales               1.0          2  Life Sciences
# 1  Research & Development               8.0          1  Life Sciences
# 2  Research & Development               2.0          2          Other
# 3  Research & Development               3.0          4  Life Sciences
# 4  Research & Development               2.0          1        Medical
#
#    EnvironmentSatisfaction  ... TotalWorkingYears  TrainingTimesLastYear  \
# 0                      2.0  ...               8.0                    0.0
# ...

# %% [markdown]
# #The number of rows and the number of columns in the dataframe

# %%
df.shape
# Out:
# (1470, 37)

# %% [markdown]
# # Let's get basic statistics about numerical columns in the dataframe.

# %%
df.describe()
# Out:
#         Unnamed: 0          Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean    734.500000    36.923810   802.485714          9.192517     2.912925
# std     424.496761     9.135373   403.509100          8.106864     1.024165
# min       0.000000    18.000000   102.000000          1.000000     1.000000
# 25%     367.250000    30.000000   465.000000          2.000000     2.000000
# 50%     734.500000    36.000000   802.000000          7.000000     3.000000
# 75%    1101.750000    43.000000  1157.000000         14.000000     4.000000
# max    1469.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# ...

# %% [markdown]
# #Generate the EDA report with SweetViz:

# %%
# Generate the EDA report with SweetViz
report = sv.analyze(df)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
# Save the report to an HTML file
report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Display the data types of each column in the DataFrame.

# %%
df.dtypes
# Out:
# Unnamed: 0                    int64
# Attrition                    object
# Age                         float64
# BusinessTravel               object
# DailyRate                   float64
# Department                   object
# DistanceFromHome            float64
# Education                     int64
# EducationField               object
# EnvironmentSatisfaction     float64
# Gender                       object
# HourlyRate                  float64
# JobInvolvement              float64
# JobLevel                    float64
# JobRole                      object
# JobSatisfaction             float64
# MaritalStatus                object
# MonthlyIncome               float64
# MonthlyRate                 float64
# NumCompaniesWorked          float64
# Over18                       object
# OverTime                     object
# PercentSalaryHike           float64
# PerformanceRating           float64
# RelationshipSatisfaction    float64
# StandardHours               float64
# ...

# %% [markdown]
# # Additional Exploratory Data Analysis

# %%
# Check the data types of each column and identify missing values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   Age                       1470 non-null   float64
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   float64
#  5   Department                1470 non-null   object
#  6   DistanceFromHome          1470 non-null   float64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1470 non-null   object
#  9   EnvironmentSatisfaction   1470 non-null   float64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   float64
#  12  JobInvolvement            1470 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Attrition', 'Age', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'SalaryAddition', 'YearlyHollidayDays',
#        'DrivingKilometers'],
#       dtype='object')

# %%
for column in df.columns:
    non_null_count= df[column].count()
    print(f"Column '{column}': Non-Null Count = {non_null_count}")
# Out:
# Column 'Unnamed: 0': Non-Null Count = 1470
# Column 'Attrition': Non-Null Count = 1470
# Column 'Age': Non-Null Count = 1470
# Column 'BusinessTravel': Non-Null Count = 1470
# Column 'DailyRate': Non-Null Count = 1470
# Column 'Department': Non-Null Count = 1470
# Column 'DistanceFromHome': Non-Null Count = 1470
# Column 'Education': Non-Null Count = 1470
# Column 'EducationField': Non-Null Count = 1470
# Column 'EnvironmentSatisfaction': Non-Null Count = 1470
# Column 'Gender': Non-Null Count = 1470
# Column 'HourlyRate': Non-Null Count = 1470
# Column 'JobInvolvement': Non-Null Count = 1470
# Column 'JobLevel': Non-Null Count = 1470
# Column 'JobRole': Non-Null Count = 1470
# Column 'JobSatisfaction': Non-Null Count = 1470
# Column 'MaritalStatus': Non-Null Count = 1470
# Column 'MonthlyIncome': Non-Null Count = 1470
# Column 'MonthlyRate': Non-Null Count = 1470
# Column 'NumCompaniesWorked': Non-Null Count = 1425
# Column 'Over18': Non-Null Count = 1470
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

categorical_nominal_columns = ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

for column in categorical_nominal_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=column, data=df)
    plt.title(f'Count Plot of {column}')
    plt.show()
